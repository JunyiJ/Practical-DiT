# %% [markdown]
# <a href="https://colab.research.google.com/github/JunyiJ/Practical-DiT/blob/main/DiT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive, userdata
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Config (Fill these in)
try:
    GITHUB_TOKEN = userdata.get('GH_TOKEN')
    GITHUB_USER = "JunyiJ"
    REPO_NAME = "Practical-DiT"
except userdata.SecretNotFoundError:
    print("❌ Secret 'GH_TOKEN' not found. Add it in the 'Secrets' tab (key icon).")

# 3. Clone or Sync
# %cd /content/drive/MyDrive
if not os.path.exists(REPO_NAME):
    # !git clone https://{GITHUB_USER}:{GITHUB_TOKEN}@github.com/{GITHUB_USER}/{REPO_NAME}.git
else:
    print(f"✅ {REPO_NAME} exists. Pulling latest changes...")
    # %cd {REPO_NAME}
    # !git pull

# 4. Set Git Identity
# !git config --global user.email "jiaojunyi90@gmail.com"
# !git config --global user.name "JunyiJ"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# ✅ Practical-DiT exists. Pulling latest changes...
# /content/drive/MyDrive/Practical-DiT
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 27 (delta 14), reused 23 (delta 14), pack-reused 4 (from 1)
# Unpacking objects: 100% (27/27), 69.18 MiB | 4.06 MiB/s, done.
# From https://github.com/JunyiJ/Practical-DiT
#    1284058..7bbdc19  main       -> origin/main
# Updating 1284058..7bbdc19
# Updating files: 100% (8/8), done.
# Fast-forward
#  .gitignore                                         |   1 -
#  ...l_checkpoint_20260310_144946_20260310_144946.pt | Bin 0 -> 39018175 bytes
#  ...200_20260311_023220_epoch200_20260311_023220.pt | Bin 0 -> 39022141 bytes
#  conf/training/cifar10_default.yaml                 |   4 ++-
#  src/diffusion.py                                   |   7 ++++
# ...

# %%
# %cd /content/drive/MyDrive/Practical-DiT
# Out:
# /content/drive/MyDrive/Practical-DiT

# %%
pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 15.5 MB/s eta 0:00:00
# ...

# %%
# !python src/train.py
# Out:
# model:
#   image_size: 32
#   patch_size: 4
#   in_channels: 3
#   hidden_size: 252
#   depth: 8
#   num_heads: 6
#   num_classes: 10
# training:
#   batch_size: 32
#   num_workers: 0
#   num_timesteps: 100
#   beta_start: 0.0001
#   beta_end: 0.02
#   lr: 0.0002
#   epochs: 150
#   checkpoint_every: 50
# device: auto
# seed: 42
#
# Using device: cuda
# ...
# Epoch 1/150 | Loss: 0.1117
# Epoch 2/150 | Loss: 0.0839
# Epoch 3/150 | Loss: 0.0816
# Epoch 4/150 | Loss: 0.0774
# Epoch 5/150 | Loss: 0.0728
# Epoch 6/150 | Loss: 0.0675
# Epoch 7/150 | Loss: 0.0653
# Epoch 8/150 | Loss: 0.0637
# Epoch 9/150 | Loss: 0.0630
# Epoch 10/150 | Loss: 0.0620
# Epoch 11/150 | Loss: 0.0623
# Epoch 12/150 | Loss: 0.0620
# Epoch 13/150 | Loss: 0.0609
# Epoch 14/150 | Loss: 0.0606
# Epoch 15/150 | Loss: 0.0612
# Epoch 16/150 | Loss: 0.0601
# Epoch 17/150 | Loss: 0.0595
# Epoch 18/150 | Loss: 0.0601
# Epoch 19/150 | Loss: 0.0591
# Epoch 20/150 | Loss: 0.0588
# Epoch 21/150 | Loss: 0.0587
# ...
